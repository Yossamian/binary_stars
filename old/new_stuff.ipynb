# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/Learning_Deep/project_954437307_066610346/
# Out:
# /content/drive/Shareddrives/Learning_Deep/project_954437307_066610346

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from pathlib import Path

# %%
# Load the new dataset to np
root_dir = Path("/content/drive/Shareddrives/Learning_Deep/project_954437307_066610346")
x_dir = root_dir.joinpath(f'new_data/final/0.npz')
data = np.load(x_dir)

# %%
"""metal_vals = [0 - 1]
alpha_vals = [-0.2 -  0.6]
temp_vals = [3500 - 6500]
logg_vals = [3 - 6]

vsini_vals= [0 - 10]
l_vals - [6992100000.0 - 485820000000.0]"""
# Out:
# 'metal_vals = [0 - 1]\nalpha_vals = [-0.2 -  0.6]\ntemp_vals = [3500 - 6500]\nlogg_vals = [3 - 6]\n\nvsini_vals= [0 - 10]\nl_vals - [6992100000.0 - 485820000000.0]'

# %%
lst = data.files
for item in lst:
    print(item)
    print(data[item].shape)

    print(np.min(data[item]), np.max(data[item]))
# Out:
# fi
# (10000, 903)
# -196.10499812143308 58.784754515928
# list_vsini_1
# (10000,)
# 0 10
# list_vsini_2
# (10000,)
# 0 10
# list_m_1
# (10000,)
# 0.0 1.0
# list_m_2
# (10000,)
# 0.0 1.0
# list_a_1
# (10000,)
# -0.2 0.6
# list_a_2
# (10000,)
# -0.2 0.6
# list_t_1
# (10000,)
# 3500 6500
# list_t_2
# (10000,)
# 3500 6500
# list_log_g_1
# (10000,)
# 3 6
# list_log_g_2
# (10000,)
# 3 6
# list_l_1
# (10000,)
# 9.844607630887449 11.686475389659822
# list_l_2
# (10000,)
# 9.844607630887449 11.686475389659822
# list_p
# (10000,)
# 30 429
# list_t
# (10000,)
# 30 429
# list_v1
# (10000,)
# 30 429
# list_v2
# (10000,)
# 30 429

# %%
for i in range(len(data['list_p'])):
  if data['list_t'][i] == data['list_v2'][i]:
    print("true")
  else:
    print("Oh")
# Out:
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# ...

# %%
# Load the new dataset to np
root_dir = Path("/content/drive/Shareddrives/Learning_Deep/project_954437307_066610346")
x_dir2 = root_dir.joinpath(f'data/2.npz')
data2 = np.load(x_dir2)
for item in data2.files:
  print(item)
  print(data2[item].shape)
# Out:
# fi
# (10160, 10197)
# list_vsini_1
# (10160,)
# list_vsini_2
# (10160,)
# list_m_1
# (10160,)
# list_m_2
# (10160,)
# list_a_1
# (10160,)
# list_a_2
# (10160,)
# list_t_1
# (10160,)
# list_t_2
# (10160,)
# list_log_g_1
# (10160,)
# list_log_g_2
# (10160,)
# list_l_1
# (10160,)
# list_l_2
# (10160,)
